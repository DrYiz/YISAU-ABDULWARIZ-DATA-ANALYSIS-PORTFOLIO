# %% [markdown]
# # Retail Revenue Performance
#
# Reproducible project validation workflow.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv('data/cleaned_data.csv')
df.head()

# %% [markdown]
# The delivered dashboard and report use the validated cleaned dataset and the accompanying high-resolution plots.
